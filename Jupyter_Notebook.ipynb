# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __Ranjith__ <br> Student

# %% [markdown]
# *I am interested in data science because it has high job opportunities and also everyone should have a grasp on it irrespective of the field*

# %% [markdown]
# ### The below code provides the remainder of 10 when divided by 3

# %%
10%3
# Out:
# 1

# %% [markdown]
#  - This is an example for bullet point <br>- this is for 2nd bullet point <br> 1. first numbered point <br> 2. 2nd numbered point <br> [link text for google](https://www.google.com/)
